# %%
import pandas as pd
import numpy as np
from arch import arch_model
from sklearn.preprocessing import StandardScaler

# === Load data ===
macro_path = 'data/Monthly Mastersheet with Original Data.xlsx'
crypto_lagged_path = 'data/All Exogenous Variables.xlsx'

df_macro = pd.read_excel(macro_path)
df_crypto_lagged = pd.read_excel(crypto_lagged_path)

# Format datetime
df_macro['Month'] = pd.to_datetime(df_macro['Month'])
df_macro.set_index('Month', inplace=True)
df_macro.index = pd.date_range(start=df_macro.index[0], periods=len(df_macro), freq='MS')

df_crypto_lagged['Month'] = pd.to_datetime(df_crypto_lagged['Month'])
df_crypto_lagged.set_index('Month', inplace=True)
df_crypto_lagged.index = pd.date_range(start=df_crypto_lagged.index[0], periods=len(df_crypto_lagged), freq='MS')

# Merge datasets
df = pd.merge(df_macro, df_crypto_lagged, left_index=True, right_index=True, how='inner')

# === Config ===
macro_vars = ['LFPR','CPI', 'r', 'M1', 'IM', 'EX', 'CC', 'GDP']
crypto_assets = ['Bitcoin', 'Litecoin', 'XRP', 'Ethereum', 'Dogecoin', 'Cardano', 'USD Coin', 'Tether']
included_lags = range(4)  # 0–3
cutoff_date = pd.to_datetime('2024-01-01')

# === Modeling ===
for macro in macro_vars:
    selected_columns = [f"{coin}_lag{lag}" for coin in crypto_assets for lag in included_lags if f"{coin}_lag{lag}" in df.columns]
    df_full = df[[macro] + selected_columns].copy()
    df_full.dropna(inplace=True)

    df_train = df_full[df_full.index < cutoff_date]

    if len(df_train) < 40:
        print(f"⚠️ Skipping {macro} due to insufficient training data.")
        continue

    y_train = df_train[[macro]]
    X_train = df_train[selected_columns]

    scaler_y = StandardScaler()
    scaler_x = StandardScaler()
    y_train_scaled = scaler_y.fit_transform(y_train).flatten()
    x_train_scaled = scaler_x.fit_transform(X_train)

    print(f"\n=== Fitting ARX-GARCH for {macro} using lags 0–3 of 8 crypto assets (32 vars) ===")

    try:
        model = arch_model(
            y_train_scaled,
            mean='ARX',
            lags=1,
            vol='GARCH',
            p=1,
            q=1,
            x=x_train_scaled,
            dist='normal',
            rescale=False
        )
        res = model.fit(disp='off', options={'maxiter': 500})

        # Map p-values to column names
        pvals = res.pvalues
        exog_pvals = {}
        for param, p in pvals.items():
            if param.startswith("x"):
                idx = int(param[1:])
                varname = X_train.columns[idx]
                exog_pvals[varname] = p

        pval_df = pd.DataFrame.from_dict(exog_pvals, orient='index', columns=['p-value'])
        pval_df.index.name = 'Variable'
        pval_df.sort_values(by='p-value', inplace=True)

        # print(f"\n=== P-values for exogenous crypto lags predicting {macro} ===")
        # print(pval_df.to_string())

    except Exception as e:
        print(f"❌ Model fitting failed for {macro}: {e}")

print(pval_df)
# Out:
# === Fitting ARX-GARCH for LFPR using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === Fitting ARX-GARCH for CPI using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === Fitting ARX-GARCH for r using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === Fitting ARX-GARCH for M1 using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === Fitting ARX-GARCH for IM using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === Fitting ARX-GARCH for EX using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === Fitting ARX-GARCH for CC using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === Fitting ARX-GARCH for GDP using lags 0–3 of 8 crypto assets (32 vars) ===
#                 p-value
# Variable
# Litecoin_lag1  0.000036
# Dogecoin_lag2  0.000182
# Ethereum_lag2  0.000316
# Bitcoin_lag2   0.003305
# Ethereum_lag1  0.006107
# Bitcoin_lag3   0.007078
# Tether_lag3    0.009607
# XRP_lag1       0.015434
# Cardano_lag3   0.025256
# Dogecoin_lag0  0.030936
# XRP_lag0       0.111738
# Ethereum_lag0  0.112371
# USD Coin_lag0  0.122621
# Tether_lag0    0.167094
# Ethereum_lag3  0.303304
# Cardano_lag1   0.315428
# Litecoin_lag3  0.368066
# Litecoin_lag2  0.418251
# XRP_lag2       0.438800
# USD Coin_lag3  0.454861
# Dogecoin_lag1  0.477973
# Litecoin_lag0  0.495480
# Bitcoin_lag0   0.567028
# USD Coin_lag1  0.579296
# Bitcoin_lag1   0.642443
# Cardano_lag0   0.651728
# Tether_lag1    0.664899
# Tether_lag2    0.840446
# Cardano_lag2   0.841511
# XRP_lag3       0.843236
# USD Coin_lag2  0.853206
# Dogecoin_lag3  0.906572
# /Users/tianyishen/Desktop/CSUREMM project/CryptoMacroecon-Prediction-CSUREMM-1/.venv/lib/python3.12/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(

# %%
# Filter significant predictors (p < 0.05)
significant_vars = pval_df[pval_df['p-value'] < 0.05].index.tolist()

print(significant_vars)


correlation_df = df[[col for col in df.columns if "lag" in col]].corr()

# === Check for high correlations among significant crypto lags ===
# === Check for high correlations among significant crypto lags ===
if significant_vars:
    # Drop missing rows/columns safely
    valid_vars = [var for var in significant_vars if var in correlation_df.index and var in correlation_df.columns]
    corr_subset = correlation_df.loc[valid_vars, valid_vars]

    high_corr_pairs = []
    for macro in macro_vars:
            for i, var1 in enumerate(valid_vars):
                for var2 in valid_vars[i+1:]:
                    try:
                        corr = corr_subset.loc[var1, var2]
                        if pd.notna(corr) and abs(corr) > 0.60:
                            high_corr_pairs.append((var1, var2, corr))
                    except KeyError:
                        continue

            if high_corr_pairs:
                print(f"\n🚨 High Correlation (>|0.60|) among significant predictors for {macro}:")
                for var1, var2, corr in high_corr_pairs:
                    print(f"{var1} & {var2}: {corr:.2f}")
            else:
                print(f"\n✅ No high correlation (>|0.60|) among significant predictors for {macro}.")
    else:
        print(f"\nℹ️ No significant crypto lags (p < 0.05) found for {macro}.")
# Out:
# ['Litecoin_lag1', 'Dogecoin_lag2', 'Ethereum_lag2', 'Bitcoin_lag2', 'Ethereum_lag1', 'Bitcoin_lag3', 'Tether_lag3', 'XRP_lag1', 'Cardano_lag3', 'Dogecoin_lag0']
#
# 🚨 High Correlation (>|0.60|) among significant predictors for LFPR:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
#
# 🚨 High Correlation (>|0.60|) among significant predictors for CPI:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
#
# 🚨 High Correlation (>|0.60|) among significant predictors for r:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
#
# 🚨 High Correlation (>|0.60|) among significant predictors for M1:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
#
# 🚨 High Correlation (>|0.60|) among significant predictors for IM:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
#
# 🚨 High Correlation (>|0.60|) among significant predictors for EX:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
#
# 🚨 High Correlation (>|0.60|) among significant predictors for CC:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
#
# 🚨 High Correlation (>|0.60|) among significant predictors for GDP:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
#
# ℹ️ No significant crypto lags (p < 0.05) found for GDP.

# %%
import pandas as pd
import numpy as np
from arch import arch_model
from sklearn.preprocessing import StandardScaler

# === Load data ===
macro_path = 'data/Monthly Mastersheet with Original Data.xlsx'
crypto_lagged_path = 'data/All Exogenous Variables.xlsx'

df_macro = pd.read_excel(macro_path)
df_crypto_lagged = pd.read_excel(crypto_lagged_path)

# Format datetime and set as index with monthly frequency
df_macro['Month'] = pd.to_datetime(df_macro['Month'])
df_macro.set_index('Month', inplace=True)
df_macro.index = pd.date_range(start=df_macro.index[0], periods=len(df_macro), freq='MS')

df_crypto_lagged['Month'] = pd.to_datetime(df_crypto_lagged['Month'])
df_crypto_lagged.set_index('Month', inplace=True)
df_crypto_lagged.index = pd.date_range(start=df_crypto_lagged.index[0], periods=len(df_crypto_lagged), freq='MS')

# Merge datasets on index (Month)
df = pd.merge(df_macro, df_crypto_lagged, left_index=True, right_index=True, how='inner')

# === Config ===
macro_vars = ['LFPR', 'CPI', 'r', 'M1', 'IM', 'EX', 'CC', 'GDP']
crypto_assets = ['Bitcoin', 'Litecoin', 'XRP', 'Ethereum', 'Dogecoin', 'Cardano', 'USD Coin', 'Tether']
included_lags = range(4)  # 0 to 3 lags
cutoff_date = pd.to_datetime('2024-01-01')

# Precompute correlation matrix once (for all crypto lag vars)
crypto_lag_cols = [f"{coin}_lag{lag}" for coin in crypto_assets for lag in included_lags if f"{coin}_lag{lag}" in df.columns]
correlation_df = df[crypto_lag_cols].corr()

for macro in macro_vars:
    selected_columns = crypto_lag_cols.copy()
    df_full = df[[macro] + selected_columns].copy()
    df_full.dropna(inplace=True)

    df_train = df_full[df_full.index < cutoff_date]

    if len(df_train) < 40:
        print(f"⚠️ Skipping {macro} due to insufficient training data.")
        continue

    y_train = df_train[[macro]]
    X_train = df_train[selected_columns]

    scaler_y = StandardScaler()
    scaler_x = StandardScaler()
    y_train_scaled = scaler_y.fit_transform(y_train).flatten()
    x_train_scaled = scaler_x.fit_transform(X_train)

    print(f"\n=== Fitting ARX-GARCH for {macro} using lags 0–3 of 8 crypto assets (32 vars) ===")

    try:
        model = arch_model(
            y_train_scaled,
            mean='ARX',
            lags=1,
            vol='GARCH',
            p=1,
            q=1,
            x=x_train_scaled,
            dist='normal',
            rescale=False
        )
        res = model.fit(disp='off', options={'maxiter': 500})

        # Extract p-values for exogenous variables (x0, x1, ...)
        pvals = res.pvalues
        exog_pvals = {}
        for param, p in pvals.items():
            if param.startswith("x"):
                idx = int(param[1:])
                varname = X_train.columns[idx]
                exog_pvals[varname] = p

        pval_df = pd.DataFrame.from_dict(exog_pvals, orient='index', columns=['p-value'])
        pval_df.index.name = 'Variable'
        pval_df.sort_values(by='p-value', inplace=True)

        print(f"\n=== P-values for exogenous crypto lags predicting {macro} ===")
        print(pval_df.to_string())

        # Filter significant predictors (p < 0.05)
        significant_vars = pval_df[pval_df['p-value'] < 0.05].index.tolist()

        if significant_vars:
            print(f"\nSignificant predictors (p < 0.05) for {macro}: {significant_vars}")

            # Check correlations among significant predictors
            valid_vars = [var for var in significant_vars if var in correlation_df.index and var in correlation_df.columns]

            if len(valid_vars) > 1:
                corr_subset = correlation_df.loc[valid_vars, valid_vars]

                high_corr_pairs = []
                for i, var1 in enumerate(valid_vars):
                    for var2 in valid_vars[i+1:]:
                        try:
                            corr = corr_subset.loc[var1, var2]
                            if pd.notna(corr) and abs(corr) > 0.60:
                                high_corr_pairs.append((var1, var2, corr))
                        except KeyError:
                            continue

                if high_corr_pairs:
                    print(f"\n🚨 High Correlation (>|0.60|) among significant predictors for {macro}:")
                    for var1, var2, corr in high_corr_pairs:
                        print(f"{var1} & {var2}: {corr:.2f}")
                else:
                    print(f"\n✅ No high correlation (>|0.60|) among significant predictors for {macro}.")
            else:
                print(f"\nℹ️ Not enough significant variables for correlation check for {macro}.")
        else:
            print(f"\nℹ️ No significant crypto lags (p < 0.05) found for {macro}.")

    except Exception as e:
        print(f"❌ Model fitting failed for {macro}: {e}")
# Out:
# === Fitting ARX-GARCH for LFPR using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === P-values for exogenous crypto lags predicting LFPR ===
#                      p-value
# Variable
# Cardano_lag0   4.325312e-109
# Tether_lag3     8.819589e-76
# Bitcoin_lag0    1.408926e-66
# XRP_lag0        1.018581e-45
# Cardano_lag2    3.396444e-40
# Tether_lag2     1.606340e-36
# USD Coin_lag3   3.925690e-34
# Bitcoin_lag3    2.501625e-31
# Bitcoin_lag1    3.092009e-29
# Ethereum_lag3   6.092198e-27
# USD Coin_lag0   6.037131e-24
# Dogecoin_lag1   2.986306e-22
# USD Coin_lag2   1.254580e-19
# Ethereum_lag1   1.767212e-18
# Tether_lag0     6.661697e-18
# Litecoin_lag1   7.857785e-17
# Litecoin_lag2   9.428422e-16
# XRP_lag2        9.277416e-15
# Cardano_lag3    4.084170e-10
# Dogecoin_lag3   2.677009e-09
# Ethereum_lag2   3.735673e-09
# Dogecoin_lag2   1.642819e-07
# XRP_lag3        2.068114e-06
# Cardano_lag1    1.969962e-04
# Dogecoin_lag0   3.733020e-04
# Litecoin_lag3   9.816210e-04
# Litecoin_lag0   1.970232e-02
# Ethereum_lag0   3.836412e-02
# Tether_lag1     4.476153e-02
# USD Coin_lag1   1.085625e-01
# XRP_lag1        1.815175e-01
# Bitcoin_lag2    4.896262e-01
#
# Significant predictors (p < 0.05) for LFPR: ['Cardano_lag0', 'Tether_lag3', 'Bitcoin_lag0', 'XRP_lag0', 'Cardano_lag2', 'Tether_lag2', 'USD Coin_lag3', 'Bitcoin_lag3', 'Bitcoin_lag1', 'Ethereum_lag3', 'USD Coin_lag0', 'Dogecoin_lag1', 'USD Coin_lag2', 'Ethereum_lag1', 'Tether_lag0', 'Litecoin_lag1', 'Litecoin_lag2', 'XRP_lag2', 'Cardano_lag3', 'Dogecoin_lag3', 'Ethereum_lag2', 'Dogecoin_lag2', 'XRP_lag3', 'Cardano_lag1', 'Dogecoin_lag0', 'Litecoin_lag3', 'Litecoin_lag0', 'Ethereum_lag0', 'Tether_lag1']
#
# 🚨 High Correlation (>|0.60|) among significant predictors for LFPR:
# Cardano_lag0 & Bitcoin_lag0: 0.66
# Cardano_lag0 & XRP_lag0: 0.73
# Cardano_lag0 & Litecoin_lag0: 0.78
# Cardano_lag0 & Ethereum_lag0: 0.81
# Tether_lag3 & Tether_lag2: 0.79
# Tether_lag3 & USD Coin_lag3: 0.86
# Tether_lag3 & USD Coin_lag0: 0.76
# Tether_lag3 & USD Coin_lag2: 0.73
# Tether_lag3 & Tether_lag0: 0.69
# Tether_lag3 & Tether_lag1: 0.75
# Bitcoin_lag0 & XRP_lag0: 0.62
# Bitcoin_lag0 & Litecoin_lag0: 0.76
# Bitcoin_lag0 & Ethereum_lag0: 0.80
# XRP_lag0 & Dogecoin_lag0: 0.61
# XRP_lag0 & Litecoin_lag0: 0.78
# XRP_lag0 & Ethereum_lag0: 0.68
# Cardano_lag2 & Litecoin_lag2: 0.78
# Cardano_lag2 & XRP_lag2: 0.73
# Cardano_lag2 & Ethereum_lag2: 0.82
# Tether_lag2 & USD Coin_lag3: 0.74
# Tether_lag2 & USD Coin_lag0: 0.77
# Tether_lag2 & USD Coin_lag2: 0.86
# Tether_lag2 & Tether_lag0: 0.75
# Tether_lag2 & Tether_lag1: 0.79
# USD Coin_lag3 & USD Coin_lag0: 0.70
# USD Coin_lag3 & USD Coin_lag2: 0.79
# USD Coin_lag3 & Tether_lag0: 0.62
# USD Coin_lag3 & Tether_lag1: 0.70
# Bitcoin_lag3 & Ethereum_lag3: 0.79
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Bitcoin_lag3 & XRP_lag3: 0.64
# Bitcoin_lag3 & Litecoin_lag3: 0.78
# Bitcoin_lag1 & Ethereum_lag1: 0.80
# Bitcoin_lag1 & Litecoin_lag1: 0.78
# Bitcoin_lag1 & Cardano_lag1: 0.67
# Ethereum_lag3 & Cardano_lag3: 0.81
# Ethereum_lag3 & XRP_lag3: 0.69
# Ethereum_lag3 & Litecoin_lag3: 0.81
# USD Coin_lag0 & USD Coin_lag2: 0.74
# USD Coin_lag0 & Tether_lag0: 0.86
# USD Coin_lag0 & Tether_lag1: 0.73
# USD Coin_lag2 & Tether_lag0: 0.70
# USD Coin_lag2 & Tether_lag1: 0.74
# Ethereum_lag1 & Litecoin_lag1: 0.81
# Ethereum_lag1 & Cardano_lag1: 0.81
# Tether_lag0 & Tether_lag1: 0.79
# Litecoin_lag1 & Cardano_lag1: 0.79
# Litecoin_lag2 & XRP_lag2: 0.78
# Litecoin_lag2 & Ethereum_lag2: 0.81
# XRP_lag2 & Ethereum_lag2: 0.69
# XRP_lag2 & Dogecoin_lag2: 0.61
# Cardano_lag3 & XRP_lag3: 0.72
# Cardano_lag3 & Litecoin_lag3: 0.78
# Dogecoin_lag3 & XRP_lag3: 0.61
# XRP_lag3 & Litecoin_lag3: 0.77
# Litecoin_lag0 & Ethereum_lag0: 0.81
#
# === Fitting ARX-GARCH for CPI using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === P-values for exogenous crypto lags predicting CPI ===
#                 p-value
# Variable
# USD Coin_lag1  0.000849
# Tether_lag1    0.008697
# Dogecoin_lag1  0.106505
# Cardano_lag3   0.133480
# Dogecoin_lag2  0.133664
# Litecoin_lag0  0.139739
# Tether_lag2    0.178404
# Bitcoin_lag0   0.207364
# Cardano_lag2   0.219530
# Bitcoin_lag2   0.225780
# XRP_lag3       0.260489
# Cardano_lag1   0.274218
# Ethereum_lag1  0.345722
# Dogecoin_lag3  0.382257
# XRP_lag0       0.425680
# Bitcoin_lag1   0.464430
# Litecoin_lag1  0.480200
# Ethereum_lag3  0.644472
# USD Coin_lag2  0.649871
# USD Coin_lag0  0.659564
# Ethereum_lag2  0.665109
# Tether_lag0    0.688243
# XRP_lag1       0.703821
# Litecoin_lag3  0.721407
# Cardano_lag0   0.757232
# Ethereum_lag0  0.779269
# Tether_lag3    0.809805
# Dogecoin_lag0  0.819049
# Bitcoin_lag3   0.886952
# Litecoin_lag2  0.889309
# XRP_lag2       0.918394
# USD Coin_lag3  0.958626
#
# Significant predictors (p < 0.05) for CPI: ['USD Coin_lag1', 'Tether_lag1']
#
# 🚨 High Correlation (>|0.60|) among significant predictors for CPI:
# USD Coin_lag1 & Tether_lag1: 0.86
#
# === Fitting ARX-GARCH for r using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === P-values for exogenous crypto lags predicting r ===
#                 p-value
# Variable
# Dogecoin_lag3  0.360172
# XRP_lag3       0.548095
# Dogecoin_lag0  0.579186
# Litecoin_lag0  0.648094
# Bitcoin_lag0   0.734107
# Ethereum_lag3  0.808130
# Dogecoin_lag1  0.814671
# Dogecoin_lag2  0.817024
# XRP_lag2       0.863340
# Litecoin_lag3  0.864898
# Ethereum_lag0  0.868815
# Bitcoin_lag2   0.879688
# Litecoin_lag2  0.881418
# Cardano_lag0   0.896557
# USD Coin_lag0  0.899291
# Tether_lag1    0.904425
# Cardano_lag2   0.916317
# USD Coin_lag2  0.926199
# Bitcoin_lag1   0.926994
# Ethereum_lag2  0.941576
# Bitcoin_lag3   0.947002
# USD Coin_lag1  0.961199
# Cardano_lag1   0.965766
# Litecoin_lag1  0.967846
# XRP_lag1       0.969701
# USD Coin_lag3  0.972790
# Tether_lag0    0.972849
# Cardano_lag3   0.987883
# XRP_lag0       0.989802
# Ethereum_lag1  0.993476
# Tether_lag3    0.994280
# Tether_lag2    0.999569
#
# ℹ️ No significant crypto lags (p < 0.05) found for r.
#
# === Fitting ARX-GARCH for M1 using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === P-values for exogenous crypto lags predicting M1 ===
#                 p-value
# Variable
# Dogecoin_lag3  0.000005
# Tether_lag1    0.001041
# Bitcoin_lag2   0.003501
# Dogecoin_lag1  0.004863
# Bitcoin_lag3   0.005408
# XRP_lag1       0.006591
# Cardano_lag0   0.006868
# XRP_lag2       0.009777
# USD Coin_lag2  0.017168
# Dogecoin_lag2  0.021248
# Tether_lag2    0.030917
# XRP_lag0       0.117622
# Litecoin_lag3  0.131146
# Dogecoin_lag0  0.158293
# Litecoin_lag2  0.160169
# Bitcoin_lag0   0.169279
# Ethereum_lag2  0.171849
# USD Coin_lag1  0.219192
# Tether_lag3    0.282672
# USD Coin_lag3  0.293392
# Cardano_lag2   0.322324
# Litecoin_lag0  0.373948
# USD Coin_lag0  0.430542
# Bitcoin_lag1   0.462007
# Cardano_lag1   0.600044
# XRP_lag3       0.622601
# Ethereum_lag3  0.681311
# Cardano_lag3   0.686324
# Ethereum_lag1  0.745372
# Tether_lag0    0.757544
# Litecoin_lag1  0.873466
# Ethereum_lag0  0.929325
#
# Significant predictors (p < 0.05) for M1: ['Dogecoin_lag3', 'Tether_lag1', 'Bitcoin_lag2', 'Dogecoin_lag1', 'Bitcoin_lag3', 'XRP_lag1', 'Cardano_lag0', 'XRP_lag2', 'USD Coin_lag2', 'Dogecoin_lag2', 'Tether_lag2']
#
# 🚨 High Correlation (>|0.60|) among significant predictors for M1:
# Tether_lag1 & USD Coin_lag2: 0.74
# Tether_lag1 & Tether_lag2: 0.79
# Bitcoin_lag2 & XRP_lag2: 0.64
# Dogecoin_lag1 & XRP_lag1: 0.61
# XRP_lag2 & Dogecoin_lag2: 0.61
# USD Coin_lag2 & Tether_lag2: 0.86
#
# === Fitting ARX-GARCH for IM using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === P-values for exogenous crypto lags predicting IM ===
#                     p-value
# Variable
# Cardano_lag1   9.433219e-36
# Bitcoin_lag3   2.621381e-19
# Litecoin_lag2  7.230625e-15
# Cardano_lag2   6.340301e-11
# Ethereum_lag3  6.841370e-09
# Dogecoin_lag0  6.696832e-07
# XRP_lag0       6.879816e-05
# Ethereum_lag2  9.769754e-05
# USD Coin_lag2  7.091924e-04
# Ethereum_lag1  1.207084e-03
# Dogecoin_lag1  2.622560e-03
# XRP_lag3       4.276268e-03
# Cardano_lag3   4.728208e-03
# Litecoin_lag0  5.055172e-03
# XRP_lag2       8.842775e-03
# Cardano_lag0   1.495379e-02
# Dogecoin_lag2  4.056868e-02
# Bitcoin_lag1   6.157379e-02
# Tether_lag0    1.065803e-01
# Litecoin_lag1  1.379882e-01
# Tether_lag2    1.386451e-01
# Ethereum_lag0  1.479421e-01
# Tether_lag3    2.435133e-01
# Litecoin_lag3  3.095969e-01
# USD Coin_lag3  3.366374e-01
# XRP_lag1       3.900561e-01
# Tether_lag1    7.070133e-01
# Dogecoin_lag3  7.109168e-01
# Bitcoin_lag0   7.692186e-01
# Bitcoin_lag2   7.850113e-01
# USD Coin_lag1  8.502573e-01
# USD Coin_lag0  9.099677e-01
#
# Significant predictors (p < 0.05) for IM: ['Cardano_lag1', 'Bitcoin_lag3', 'Litecoin_lag2', 'Cardano_lag2', 'Ethereum_lag3', 'Dogecoin_lag0', 'XRP_lag0', 'Ethereum_lag2', 'USD Coin_lag2', 'Ethereum_lag1', 'Dogecoin_lag1', 'XRP_lag3', 'Cardano_lag3', 'Litecoin_lag0', 'XRP_lag2', 'Cardano_lag0', 'Dogecoin_lag2']
#
# 🚨 High Correlation (>|0.60|) among significant predictors for IM:
# Cardano_lag1 & Ethereum_lag1: 0.81
# Bitcoin_lag3 & Ethereum_lag3: 0.79
# Bitcoin_lag3 & XRP_lag3: 0.64
# Bitcoin_lag3 & Cardano_lag3: 0.67
# Litecoin_lag2 & Cardano_lag2: 0.78
# Litecoin_lag2 & Ethereum_lag2: 0.81
# Litecoin_lag2 & XRP_lag2: 0.78
# Cardano_lag2 & Ethereum_lag2: 0.82
# Cardano_lag2 & XRP_lag2: 0.73
# Ethereum_lag3 & XRP_lag3: 0.69
# Ethereum_lag3 & Cardano_lag3: 0.81
# Dogecoin_lag0 & XRP_lag0: 0.61
# XRP_lag0 & Litecoin_lag0: 0.78
# XRP_lag0 & Cardano_lag0: 0.73
# Ethereum_lag2 & XRP_lag2: 0.69
# XRP_lag3 & Cardano_lag3: 0.72
# Litecoin_lag0 & Cardano_lag0: 0.78
# XRP_lag2 & Dogecoin_lag2: 0.61
#
# === Fitting ARX-GARCH for EX using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === P-values for exogenous crypto lags predicting EX ===
#                      p-value
# Variable
# Litecoin_lag2  1.985105e-201
# USD Coin_lag0   1.296249e-48
# XRP_lag1        8.702668e-36
# USD Coin_lag2   1.998238e-29
# XRP_lag0        2.391010e-24
# Bitcoin_lag0    4.717682e-21
# Cardano_lag0    5.504124e-15
# Tether_lag3     6.492441e-15
# Ethereum_lag2   8.862225e-15
# Dogecoin_lag2   4.401661e-14
# USD Coin_lag3   5.011088e-12
# Ethereum_lag3   4.762760e-11
# Bitcoin_lag3    1.922559e-08
# Ethereum_lag0   2.866484e-07
# Litecoin_lag3   7.002834e-06
# XRP_lag3        7.259404e-06
# XRP_lag2        9.871793e-06
# Tether_lag0     5.373051e-05
# Cardano_lag1    3.190863e-04
# Dogecoin_lag1   5.333496e-04
# Bitcoin_lag1    7.923424e-04
# Ethereum_lag1   8.736816e-04
# Litecoin_lag0   2.459119e-03
# Tether_lag1     9.430929e-03
# Cardano_lag3    5.404988e-02
# USD Coin_lag1   6.621569e-02
# Dogecoin_lag3   2.653602e-01
# Tether_lag2     2.873903e-01
# Dogecoin_lag0   3.520087e-01
# Litecoin_lag1   5.044859e-01
# Bitcoin_lag2    6.939012e-01
# Cardano_lag2    7.466949e-01
#
# Significant predictors (p < 0.05) for EX: ['Litecoin_lag2', 'USD Coin_lag0', 'XRP_lag1', 'USD Coin_lag2', 'XRP_lag0', 'Bitcoin_lag0', 'Cardano_lag0', 'Tether_lag3', 'Ethereum_lag2', 'Dogecoin_lag2', 'USD Coin_lag3', 'Ethereum_lag3', 'Bitcoin_lag3', 'Ethereum_lag0', 'Litecoin_lag3', 'XRP_lag3', 'XRP_lag2', 'Tether_lag0', 'Cardano_lag1', 'Dogecoin_lag1', 'Bitcoin_lag1', 'Ethereum_lag1', 'Litecoin_lag0', 'Tether_lag1']
#
# 🚨 High Correlation (>|0.60|) among significant predictors for EX:
# Litecoin_lag2 & Ethereum_lag2: 0.81
# Litecoin_lag2 & XRP_lag2: 0.78
# USD Coin_lag0 & USD Coin_lag2: 0.74
# USD Coin_lag0 & Tether_lag3: 0.76
# USD Coin_lag0 & USD Coin_lag3: 0.70
# USD Coin_lag0 & Tether_lag0: 0.86
# USD Coin_lag0 & Tether_lag1: 0.73
# XRP_lag1 & Cardano_lag1: 0.73
# XRP_lag1 & Dogecoin_lag1: 0.61
# XRP_lag1 & Bitcoin_lag1: 0.64
# XRP_lag1 & Ethereum_lag1: 0.69
# USD Coin_lag2 & Tether_lag3: 0.73
# USD Coin_lag2 & USD Coin_lag3: 0.79
# USD Coin_lag2 & Tether_lag0: 0.70
# USD Coin_lag2 & Tether_lag1: 0.74
# XRP_lag0 & Bitcoin_lag0: 0.62
# XRP_lag0 & Cardano_lag0: 0.73
# XRP_lag0 & Ethereum_lag0: 0.68
# XRP_lag0 & Litecoin_lag0: 0.78
# Bitcoin_lag0 & Cardano_lag0: 0.66
# Bitcoin_lag0 & Ethereum_lag0: 0.80
# Bitcoin_lag0 & Litecoin_lag0: 0.76
# Cardano_lag0 & Ethereum_lag0: 0.81
# Cardano_lag0 & Litecoin_lag0: 0.78
# Tether_lag3 & USD Coin_lag3: 0.86
# Tether_lag3 & Tether_lag0: 0.69
# Tether_lag3 & Tether_lag1: 0.75
# Ethereum_lag2 & XRP_lag2: 0.69
# Dogecoin_lag2 & XRP_lag2: 0.61
# USD Coin_lag3 & Tether_lag0: 0.62
# USD Coin_lag3 & Tether_lag1: 0.70
# Ethereum_lag3 & Bitcoin_lag3: 0.79
# Ethereum_lag3 & Litecoin_lag3: 0.81
# Ethereum_lag3 & XRP_lag3: 0.69
# Bitcoin_lag3 & Litecoin_lag3: 0.78
# Bitcoin_lag3 & XRP_lag3: 0.64
# Ethereum_lag0 & Litecoin_lag0: 0.81
# Litecoin_lag3 & XRP_lag3: 0.77
# Tether_lag0 & Tether_lag1: 0.79
# Cardano_lag1 & Bitcoin_lag1: 0.67
# Cardano_lag1 & Ethereum_lag1: 0.81
# Bitcoin_lag1 & Ethereum_lag1: 0.80
#
# === Fitting ARX-GARCH for CC using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === P-values for exogenous crypto lags predicting CC ===
#                 p-value
# Variable
# Litecoin_lag1  0.000043
# USD Coin_lag2  0.000127
# Litecoin_lag2  0.000353
# USD Coin_lag3  0.000774
# Ethereum_lag2  0.003540
# Ethereum_lag0  0.003626
# Ethereum_lag3  0.004770
# Cardano_lag0   0.004830
# Tether_lag0    0.007572
# Dogecoin_lag2  0.007804
# Tether_lag1    0.013582
# USD Coin_lag1  0.016234
# XRP_lag3       0.023623
# Dogecoin_lag3  0.026306
# XRP_lag2       0.027163
# Tether_lag3    0.029121
# Tether_lag2    0.040669
# Ethereum_lag1  0.040681
# Cardano_lag3   0.083372
# USD Coin_lag0  0.122041
# XRP_lag0       0.162189
# Cardano_lag2   0.165462
# Bitcoin_lag1   0.178709
# Dogecoin_lag0  0.202103
# XRP_lag1       0.257151
# Cardano_lag1   0.266562
# Bitcoin_lag2   0.272154
# Dogecoin_lag1  0.298503
# Litecoin_lag3  0.736801
# Bitcoin_lag3   0.739678
# Litecoin_lag0  0.743473
# Bitcoin_lag0   0.983185
#
# Significant predictors (p < 0.05) for CC: ['Litecoin_lag1', 'USD Coin_lag2', 'Litecoin_lag2', 'USD Coin_lag3', 'Ethereum_lag2', 'Ethereum_lag0', 'Ethereum_lag3', 'Cardano_lag0', 'Tether_lag0', 'Dogecoin_lag2', 'Tether_lag1', 'USD Coin_lag1', 'XRP_lag3', 'Dogecoin_lag3', 'XRP_lag2', 'Tether_lag3', 'Tether_lag2', 'Ethereum_lag1']
#
# 🚨 High Correlation (>|0.60|) among significant predictors for CC:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# USD Coin_lag2 & USD Coin_lag3: 0.79
# USD Coin_lag2 & Tether_lag0: 0.70
# USD Coin_lag2 & Tether_lag1: 0.74
# USD Coin_lag2 & USD Coin_lag1: 0.78
# USD Coin_lag2 & Tether_lag3: 0.73
# USD Coin_lag2 & Tether_lag2: 0.86
# Litecoin_lag2 & Ethereum_lag2: 0.81
# Litecoin_lag2 & XRP_lag2: 0.78
# USD Coin_lag3 & Tether_lag0: 0.62
# USD Coin_lag3 & Tether_lag1: 0.70
# USD Coin_lag3 & USD Coin_lag1: 0.74
# USD Coin_lag3 & Tether_lag3: 0.86
# USD Coin_lag3 & Tether_lag2: 0.74
# Ethereum_lag2 & XRP_lag2: 0.69
# Ethereum_lag0 & Cardano_lag0: 0.81
# Ethereum_lag3 & XRP_lag3: 0.69
# Tether_lag0 & Tether_lag1: 0.79
# Tether_lag0 & USD Coin_lag1: 0.74
# Tether_lag0 & Tether_lag3: 0.69
# Tether_lag0 & Tether_lag2: 0.75
# Dogecoin_lag2 & XRP_lag2: 0.61
# Tether_lag1 & USD Coin_lag1: 0.86
# Tether_lag1 & Tether_lag3: 0.75
# Tether_lag1 & Tether_lag2: 0.79
# USD Coin_lag1 & Tether_lag3: 0.77
# USD Coin_lag1 & Tether_lag2: 0.73
# XRP_lag3 & Dogecoin_lag3: 0.61
# Tether_lag3 & Tether_lag2: 0.79
#
# === Fitting ARX-GARCH for GDP using lags 0–3 of 8 crypto assets (32 vars) ===
#
# === P-values for exogenous crypto lags predicting GDP ===
#                 p-value
# Variable
# Litecoin_lag1  0.000036
# Dogecoin_lag2  0.000182
# Ethereum_lag2  0.000316
# Bitcoin_lag2   0.003305
# Ethereum_lag1  0.006107
# Bitcoin_lag3   0.007078
# Tether_lag3    0.009607
# XRP_lag1       0.015434
# Cardano_lag3   0.025256
# Dogecoin_lag0  0.030936
# XRP_lag0       0.111738
# Ethereum_lag0  0.112371
# USD Coin_lag0  0.122621
# Tether_lag0    0.167094
# Ethereum_lag3  0.303304
# Cardano_lag1   0.315428
# Litecoin_lag3  0.368066
# Litecoin_lag2  0.418251
# XRP_lag2       0.438800
# USD Coin_lag3  0.454861
# Dogecoin_lag1  0.477973
# Litecoin_lag0  0.495480
# Bitcoin_lag0   0.567028
# USD Coin_lag1  0.579296
# Bitcoin_lag1   0.642443
# Cardano_lag0   0.651728
# Tether_lag1    0.664899
# Tether_lag2    0.840446
# Cardano_lag2   0.841511
# XRP_lag3       0.843236
# USD Coin_lag2  0.853206
# Dogecoin_lag3  0.906572
#
# Significant predictors (p < 0.05) for GDP: ['Litecoin_lag1', 'Dogecoin_lag2', 'Ethereum_lag2', 'Bitcoin_lag2', 'Ethereum_lag1', 'Bitcoin_lag3', 'Tether_lag3', 'XRP_lag1', 'Cardano_lag3', 'Dogecoin_lag0']
#
# 🚨 High Correlation (>|0.60|) among significant predictors for GDP:
# Litecoin_lag1 & Ethereum_lag1: 0.81
# Litecoin_lag1 & XRP_lag1: 0.78
# Ethereum_lag2 & Bitcoin_lag2: 0.80
# Ethereum_lag1 & XRP_lag1: 0.69
# Bitcoin_lag3 & Cardano_lag3: 0.67
# /Users/tianyishen/Desktop/CSUREMM project/CryptoMacroecon-Prediction-CSUREMM-1/.venv/lib/python3.12/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
